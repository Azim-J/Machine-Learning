# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("train.csv")
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df.describe(include="all")
# Out:
#        Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# count             8523  7060.000000             8523      8523.000000
# unique            1559          NaN                5              NaN
# top              FDG33          NaN          Low Fat              NaN
# freq                10          NaN             5089              NaN
# mean               NaN    12.857645              NaN         0.066132
# std                NaN     4.643456              NaN         0.051598
# min                NaN     4.555000              NaN         0.000000
# 25%                NaN     8.773750              NaN         0.026989
# 50%                NaN    12.600000              NaN         0.053931
# 75%                NaN    16.850000              NaN         0.094585
# max                NaN    21.350000              NaN         0.328391
#
#                     Item_Type     Item_MRP Outlet_Identifier  \
# count                    8523  8523.000000              8523
# ...

# %%
#Using intuitions, some good features may be Item_Type, Item_Visibility, Item_MRP, Outlet_Location_Type, Outlet_Type
sns.barplot(data=df, x="Item_Type", y="Item_Outlet_Sales")
# Out:
# <Axes: xlabel='Item_Type', ylabel='Item_Outlet_Sales'>

# %%
sns.regplot(data=df, x="Item_Visibility", y="Item_Outlet_Sales", color="red")
# Out:
# <Axes: xlabel='Item_Visibility', ylabel='Item_Outlet_Sales'>

# %%
sns.regplot(data=df, x="Item_MRP", y="Item_Outlet_Sales", line_kws={'color': 'red'})
# Out:
# <Axes: xlabel='Item_MRP', ylabel='Item_Outlet_Sales'>

# %%
sns.barplot(data=df, x="Outlet_Location_Type", y="Item_Outlet_Sales")
# Out:
# <Axes: xlabel='Outlet_Location_Type', ylabel='Item_Outlet_Sales'>

# %%
sns.barplot(data=df, x="Outlet_Type", y="Item_Outlet_Sales")
# Out:
# <Axes: xlabel='Outlet_Type', ylabel='Item_Outlet_Sales'>

# %%
#Features to use: Outlet_Type, Outlet_Location_Type, Item_MRP
df["Item_Fat_Content"].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: count, dtype: int64

# %%
sns.barplot(data=df, x="Outlet_Identifier", y="Item_Outlet_Sales")
# Out:
# <Axes: xlabel='Outlet_Identifier', ylabel='Item_Outlet_Sales'>
